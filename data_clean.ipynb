# %%
import pandas as pd

data = pd.read_csv("animaux_nettoyes.csv")
data.head()
# Out:
#                   Nom_Details            Prix  \
# 0                       Chien          100000
# 1      Chiots Bichons Maltais          250000
# 2  Chiot berger malinois male          250000
# 3  Chiot Bouledogues français  Prixsurdemande
# 4       Chiot Berger Malinois          250000
#
#                                     Adresse  \
# 0            location_onDiamniadio, Sénégal
# 1           location_onMbao, Dakar, Sénégal
# 2  location_onSicap Liberté, Dakar, Sénégal
# 3        location_onPoint E, Dakar, Sénégal
# 4  location_onSicap Liberté, Dakar, Sénégal
#
#                                           Image_Lien Categorie
# 0  https://images.coinafrique.com/thumb_5769939_u...    Chiens
# 1  https://images.coinafrique.com/thumb_5768774_u...    Chiens
# 2  https://images.coinafrique.com/thumb_5763030_u...    Chiens
# 3  https://images.coinafrique.com/thumb_5757166_u...    Chiens
# 4  https://images.coinafrique.com/thumb_5755635_u...    Chiens

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nom_Details  672 non-null    object
#  1   Prix         672 non-null    object
#  2   Adresse      672 non-null    object
#  3   Image_Lien   672 non-null    object
#  4   Categorie    672 non-null    object
# dtypes: object(5)
# memory usage: 26.4+ KB
